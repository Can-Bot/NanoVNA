# %% [markdown]
# # Sample notebook to interact with NanoVNA

# %%
# %matplotlib inline
from nanovna import NanoVNA
#reload script
# %run nanovna.py

# %%
# create instance and connect to the device
nv = NanoVNA()

# %%
nv.set_sweep(1e6, 500e6)
nv.fetch_frequencies()

# %%
s11 = nv.data(0)
s12 = nv.data(1)

# %%
nv.logmag(s11)
nv.logmag(s12)

# %%
nv.phase(s12)

# %% [markdown]
# ## Various plots by scikit-rf

# %%
n = nv.smith(s11)

# %%
n.plot_s_deg()

# %%
n.plot_s_db()

# %% [markdown]
# ## read/write touchstone file

# %%
n.write_touchstone('100mhz-lpf-s11')

# %%
import skrf
m = skrf.Network('100mhz-lpf-s11.s1p')

# %% [markdown]
# ## read/write by skrf network format

# %%
n.write('100mhz-lpf')
# Out:
# <class 'skrf.frequency.Frequency'> freq
# <class 'skrf.network.Network'> ntwk

# %%
import skrf
skrf.read('100mhz-lpf.ntwk')
# Out:
# 1-Port Network: '',  1.0-500.0 MHz, 101 pts, z0=[50.+0.j]
